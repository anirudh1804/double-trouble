# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\AI Code\NLP\Duplicate Question Pairs\train.csv\train.csv")
df.shape
# Out:
# (404290, 6)

# %%
df.sample(10)
# Out:
#             id    qid1    qid2  \
# 229366  229366  338642  338643
# 155340  155340  243377  243378
# 282892  282892  402917  402918
# 212942  212942  117899  138713
# 140851  140851  223757  223758
# 24750    24750   46200   46201
# 105420  105420  173846   38699
# 301777  301777  424724  424725
# 386209  386209  518390  378429
# 123287  123287  199366  199367
#
#                                                 question1  \
# 229366                               I earn 80 LPA india?
# 155340  What should I know about human behavior if I w...
# 282892  Is monarchy possible without any tie to religion?
# 212942  What is the strangest food you have ever eaten...
# 140851  What is the best response when someone talks t...
# 24750   Who are the most overrated actors and actresse...
# 105420        How can an Indian become scientist at NASA?
# 301777     What life lessons does Romeo and Juliet teach?
# 386209             What do Atheists think about marriage?
# 123287  Which startups have the strongest engineering ...
#
#                                                 question2  is_duplicate
# 229366  What are girls earning 10 LPA interested in? I...             0
# 155340  What should I know about human behaviour if I ...             1
# 282892  Startup (scalable) med device class 1, 2. Glov...             0
# 212942   What was the strangest food you have ever eaten?             1
# 140851  The person who was ignoring me started talking...             0
# 24750   Who are the most overrated actors/actresses in...             0
# 105420             How do I get a job in NASA from India?             0
# 301777  How was Romeo & Juliet received during Shakesp...             0
# 386209                     How do atheists view marriage?             1
# 123287  What is the best advice for a young, first-tim...             0

# %%
# missing values
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
# duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Distribution of duplicate and non-duplicate questions

print(df['is_duplicate'].value_counts())
print((df['is_duplicate'].value_counts()/df['is_duplicate'].count())*100)
df['is_duplicate'].value_counts().plot(kind='bar')
# Out:
# is_duplicate
# 0    255027
# 1    149263
# Name: count, dtype: int64
# is_duplicate
# 0    63.080215
# 1    36.919785
# Name: count, dtype: float64
# <Axes: xlabel='is_duplicate'>

# %%
# Repeated questions

qid = pd.Series(df['qid1'].tolist() + df['qid2'].tolist())
print('Number of unique questions',np.unique(qid).shape[0])
x = qid.value_counts()>1
print('Number of questions getting repeated',x[x].shape[0])
# Out:
# Number of unique questions 537933
# Number of questions getting repeated 111780

# %%
# Repeated questions histogram

plt.hist(qid.value_counts().values,bins=160)
plt.yscale('log')
plt.show()
